# %%
#  step through years and visualize in PCA space

import mysql.connector as mysql
import pickle
import json

import numpy as np
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['svg.fonttype'] = 'none'

import time

# %% [markdown]
# ### mysql client

# %%
db_name = 'test_pubmed'  # db name collisons? https://stackoverflow.com/questions/14011968/user-cant-access-a-database
client_config = {'unix_socket':'/home/brendanchambers/.sql.sock',
                'database': db_name,
                'use_pure': True}  # for python connector
output_path = '/project2/jevans/brendan/pubmed_data_processing/year_pmids/'

# %% [markdown]
# ## load pre-fit pca model

# %%
pca_path = 'develop_samples/pca_model1.pkl'  # more located at /project2...
with open(pca_path, 'rb') as file:
    pca_model = pickle.load(file)

# %% [markdown]
# # load year publication pmids  & join to embeddings
#
# (todo join to text as well)

# %%
start_year = 1958
end_year = 2018
D_truncate = 300
path2dir = '/project2/jevans/brendan/pubmed_data_processing/year_pmids/'

year_pubs = {}
for year in range(start_year, end_year+1):
    
    print('{}...'.format(year))
    
    db = mysql.connect(**client_config)

    filename = 'pubmed_state_{}'.format(year)
    path2pmids = path2dir + filename
    with open(path2pmids,'r') as f:
        data = json.load(f)
    
    year_pub_pmids = data['publications']
    N_pubs = len(year_pub_pmids)
    print("N pubs: {}".format(N_pubs))
    del data # clean up
    
    str_fmt = ', '.join([str(pmid) for pmid in year_pub_pmids])
    
    sql = '''SELECT E.pmid, E.embedding
            FROM scibert_mean_embedding as E
            WHERE E.pmid IN ({})'''.format(str_fmt)
    
    start_time = time.time()
    cursor = db.cursor(buffered=False)
    cursor.execute(sql)
    end_time = time.time()
    elapsed = end_time - start_time
    print("SQL join executed in {} s".format(elapsed))

    start_time = time.time()
    pub_embeddings = []
    pub_pmids = []
    for i,row in enumerate(cursor):
        print_block_len = 100000
        if i % print_block_len == 0:
            print('fetched {} rows...'.format(print_block_len))
        pub_pmids.append(row[0])
        pub_embeddings.append(np.frombuffer(row[1],dtype='float64').tolist())
    cursor.close()
    end_time = time.time()
    elapsed = end_time - start_time
    print("SQL results fetched and cast in {} s".format(elapsed))
    
    start_time = time.time()
    #year_pubs[year] = pca_model.transform(pub_embeddings)[:,:D_truncate]
    end_time = time.time()
    elapsed = end_time - start_time
    print("pca transform finished in {} s".format(elapsed))
    
    start_time = time.time()
    path = output_path + 'publication_embeddings/' + str(year) + '.json'
    save_obj = {'pmids': pub_pmids,
                'embeddings': pub_embeddings}
    with open(path,'w') as f:
        json.dump(save_obj, f)
    end_time = time.time()
    elapsed = end_time - start_time
    print('finished writing output file in {} s...'.format(elapsed))
        
    print()
# Out:
# 1958...
# N pubs: 109432
# SQL join executed in 0.38938164710998535 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 60.227108001708984 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 117.28796410560608 s...
#
# 1959...
# N pubs: 109952
# SQL join executed in 0.46601271629333496 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 74.25713181495667 s
# pca transform finished in 7.152557373046875e-07 s
# finished writing output file in 119.27769827842712 s...
#
# 1960...
# N pubs: 112169
# SQL join executed in 0.9044733047485352 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 125.56717133522034 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 119.87176775932312 s...
#
# 1961...
# N pubs: 120124
# SQL join executed in 0.6382238864898682 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 130.4963755607605 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 129.85991954803467 s...
#
# 1962...
# N pubs: 125695
# SQL join executed in 0.8637852668762207 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 97.71060299873352 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 135.57516407966614 s...
#
# 1963...
# N pubs: 141435
# SQL join executed in 6.185936450958252 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 107.81243801116943 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 152.247145652771 s...
#
# 1964...
# N pubs: 162041
# SQL join executed in 1.8884565830230713 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 173.95006704330444 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 174.67639446258545 s...
#
# 1965...
# N pubs: 176673
# SQL join executed in 0.6694400310516357 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 150.44605827331543 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 191.18793439865112 s...
#
# 1966...
# N pubs: 180095
# SQL join executed in 0.9304766654968262 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 179.95337438583374 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 193.42827606201172 s...
#
# 1967...
# N pubs: 191978
# SQL join executed in 1.6031229496002197 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 205.65928673744202 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 207.01125764846802 s...
#
# 1968...
# N pubs: 208065
# SQL join executed in 2.74735426902771 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 195.87157034873962 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 220.43901562690735 s...
#
# 1969...
# N pubs: 215271
# SQL join executed in 2.8591010570526123 s
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 189.02264404296875 s
# pca transform finished in 7.152557373046875e-07 s
# finished writing output file in 197.58081436157227 s...
#
# 1970...
# N pubs: 219342
# SQL join executed in 0.49810004234313965 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 192.68024277687073 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 226.43280935287476 s...
#
# 1971...
# N pubs: 223591
# SQL join executed in 0.7734525203704834 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 175.41657710075378 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 232.90572834014893 s...
#
# 1972...
# N pubs: 227791
# SQL join executed in 0.8270394802093506 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 195.24501585960388 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 238.73855996131897 s...
#
# 1973...
# N pubs: 231054
# SQL join executed in 1.1165623664855957 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 270.5313296318054 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 251.34759783744812 s...
#
# 1974...
# N pubs: 235032
# SQL join executed in 2.1162195205688477 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 198.20559191703796 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 251.85921788215637 s...
#
# 1975...
# N pubs: 249130
# SQL join executed in 0.8576822280883789 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 310.472128868103 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 262.626855134964 s...
#
# 1976...
# N pubs: 254892
# SQL join executed in 1.7514288425445557 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 308.22379422187805 s
# pca transform finished in 7.152557373046875e-07 s
# finished writing output file in 275.9747929573059 s...
#
# 1977...
# N pubs: 262150
# SQL join executed in 1.2633612155914307 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 403.0769238471985 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 282.6194877624512 s...
#
# 1978...
# N pubs: 272508
# SQL join executed in 0.9475069046020508 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 368.3352961540222 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 289.3394720554352 s...
#
# 1979...
# N pubs: 282049
# SQL join executed in 1.7661805152893066 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 309.6725289821625 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 304.2561888694763 s...
#
# 1980...
# N pubs: 280603
# SQL join executed in 1.8107068538665771 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 441.6996865272522 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 291.51264238357544 s...
#
# 1981...
# N pubs: 283505
# SQL join executed in 2.2111666202545166 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 388.45077180862427 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 291.98954820632935 s...
#
# 1982...
# N pubs: 295569
# SQL join executed in 3.346186637878418 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 311.43645906448364 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 297.15577721595764 s...
#
# 1983...
# N pubs: 309368
# SQL join executed in 5.811937570571899 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 309.1202390193939 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 277.2741391658783 s...
#
# 1984...
# N pubs: 318104
# SQL join executed in 0.9748356342315674 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 234.31845450401306 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 331.80451130867004 s...
#
# 1985...
# N pubs: 335114
# SQL join executed in 0.9565389156341553 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 278.9824364185333 s
# pca transform finished in 7.152557373046875e-07 s
# finished writing output file in 356.5178656578064 s...
#
# 1986...
# N pubs: 349462
# SQL join executed in 1.583665132522583 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 357.34299063682556 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 377.114905834198 s...
#
# 1987...
# N pubs: 367778
# SQL join executed in 1.5504462718963623 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 339.93264293670654 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 397.4475622177124 s...
#
# 1988...
# N pubs: 386677
# SQL join executed in 3.1321213245391846 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 315.91997241973877 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 413.0181543827057 s...
#
# 1989...
# N pubs: 402283
# SQL join executed in 1.9011433124542236 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 323.1846158504486 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 419.6739354133606 s...
#
# 1990...
# N pubs: 410220
# SQL join executed in 1.357069492340088 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 346.8853816986084 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 437.520391702652 s...
#
# 1991...
# N pubs: 412763
# SQL join executed in 1.3822076320648193 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 310.53888726234436 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 396.54936003685 s...
#
# 1992...
# N pubs: 417516
# SQL join executed in 1.2233128547668457 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 338.19726514816284 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 445.9044952392578 s...
#
# 1993...
# N pubs: 426264
# SQL join executed in 1.7929913997650146 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 408.2235848903656 s
# pca transform finished in 7.152557373046875e-07 s
# finished writing output file in 444.3148112297058 s...
#
# 1994...
# N pubs: 437768
# SQL join executed in 2.442833185195923 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 456.4083182811737 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 447.49907064437866 s...
#
# 1995...
# N pubs: 448593
# SQL join executed in 1.0814123153686523 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 492.6758677959442 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 441.77978801727295 s...
#
# 1996...
# N pubs: 458126
# SQL join executed in 1.9051995277404785 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 477.4834403991699 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 482.0159327983856 s...
#
# 1997...
# N pubs: 456281
# SQL join executed in 3.0455803871154785 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 470.87435269355774 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 476.9662721157074 s...
#
# 1998...
# N pubs: 474479
# SQL join executed in 2.2916011810302734 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 435.706330537796 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 503.41442370414734 s...
#
# 1999...
# N pubs: 493485
# SQL join executed in 1.9123423099517822 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 513.9464707374573 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 519.819771528244 s...
#
# 2000...
# N pubs: 530246
# SQL join executed in 2.517688751220703 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 511.59422969818115 s
# pca transform finished in 4.76837158203125e-07 s
# finished writing output file in 555.0841217041016 s...
#
# 2001...
# N pubs: 543554
# SQL join executed in 2.965747356414795 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 546.2992870807648 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 584.045595407486 s...
#
# 2002...
# N pubs: 558647
# SQL join executed in 3.7072460651397705 s
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# fetched 100000 rows...
# SQL results fetched and cast in 506.9545636177063 s
# pca transform finished in 2.384185791015625e-07 s
# finished writing output file in 594.354945898056 s...
#
# 2003...
# N pubs: 583939
# SQL join executed in 4.246990919113159 s
# fetched 100000 rows...

# %% [markdown]
# # load year citation pmids, join to embeddings

# %%
year_cites = {}

for year in range(start_year, end_year+1):
    
    print('{}...'.format(year))
    
    db = mysql.connect(**client_config)

    filename = 'pubmed_state_{}'.format(year)
    path2pmids = path2dir + filename
    with open(path2pmids,'r') as f:
        data = json.load(f)
    
    year_cite_pmids = data['citations']
    del data # clean up
    N_citations = len(year_cite_pmids)
    print("N citations: {}".format(N_citations))
    
    str_fmt = ', '.join([str(pmid) for pmid in year_cite_pmids])
    
    sql = '''SELECT E.pmid, E.embedding
            FROM scibert_mean_embedding as E
            WHERE E.pmid IN ({})'''.format(str_fmt)
    
    start_time = time.time()
    cursor = db.cursor(buffered=False)
    cursor.execute(sql)
    end_time = time.time()
    elapsed = end_time - start_time
    print("SQL join executed in {} s".format(elapsed))

    start_time = time.time()
    cite_embeddings = []
    cite_pmids = []
    for i,row in enumerate(cursor):
        print_block_len = 100000
        if i % print_block_len == 0:
            print('fetched {} rows...'.format(print_block_len))
        cite_pmids.append(row[0])
        cite_embeddings.append(np.frombuffer(row[1],dtype='float64').tolist())

    cursor.close()
    print('fetched')

    end_time = time.time()
    elapsed = end_time - start_time
    print("SQL results fetched and cast in {} s".format(elapsed))

    start_time = time.time()
    #year_cites[year] = pca_model.transform(cite_embeddings)[:,:D_truncate]
    end_time = time.time()
    elapsed = end_time - start_time
    print("pca transform finished in {} s".format(elapsed))
        
    start_time = time.time()
    path = output_path + 'citation_embeddings/' + str(year) + '.json'
    save_obj = {'pmids': cite_pmids,
                'embeddings': cite_embeddings}
    with open(path,'w') as f:
        json.dump(save_obj, f)
    end_time = time.time()
    elapsed = end_time - start_time
    print('finished writing output file in {} s'.format(elapsed))
    
    db.close()
    print()

# %% [markdown]
# ### plot publications and citations

# %%
# todo - use this as raw material for a separate plotting script

def plot_pubs_and_cites(start_year, end_year):
    (f, ax) = plt.subplots(end_year - start_year + 1,
                       2,
                       sharex='all', sharey='all',
                       figsize=(4,4))

    for i_year, year in enumerate(range(start_year, end_year+1)):

        print(i_year, year)

        sns.kdeplot(year_pubs[year][:,0],
                    year_pubs[year][:,1],
                    ax=ax[i_year,0],
                    shade=True,
                    cmap='Blues')
        ax[i_year,0].set_title('published: year {}'.format(year))


        sns.kdeplot(year_cites[year][:,0],
                    year_cites[year][:,1],
                    ax=ax[i_year,1],
                    shade=True,
                    cmap='Reds')
        ax[i_year,1].set_title('cited: {}'.format(year))

    plt.savefig('publications and citations prototype {} - {}.png'.format(start_year, end_year))
    plt.savefig('publications and citations prototype {} - {}.svg'.format(start_year, end_year))
    plt.show()

# %%
plot_pubs_and_cites(start_year, end_year)
